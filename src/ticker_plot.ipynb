# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime

# %%
ticker1 = 'ADX'
ticker2 = 'CSX'

# %%
df1 = pd.read_pickle("data/raw/" + ticker1 + ".zip")  # needs pickle5 compression (python 3.8)
df2 = pd.read_pickle("data/raw/" + ticker2 + ".zip")  # needs pickle5 compression (python 3.8)

# %%
df1
# Out:
#                  High        Low       Open      Close    Volume  Adj Close  \
# Date
# 1999-01-04  18.000000  17.666668  17.666668  17.750000   80850.0   4.047894
# 1999-01-05  17.958332  17.750000  17.750000  17.916668   75300.0   4.085901
# 1999-01-06  18.333332  18.000000  18.000000  18.291668  118500.0   4.171421
# 1999-01-07  18.208332  18.041668  18.083332  18.166668  111300.0   4.142914
# 1999-01-08  18.375000  18.083332  18.208332  18.250000  149550.0   4.161918
# ...               ...        ...        ...        ...       ...        ...
# 2021-02-23  17.860001  17.580000  17.780001  17.799999  212900.0  17.799999
# 2021-02-24  18.020000  17.650000  17.750000  18.020000  225300.0  18.020000
# 2021-02-25  18.049999  17.530001  17.969999  17.650000  147200.0  17.650000
# 2021-02-26  17.809999  17.559999  17.790001  17.590000  212100.0  17.590000
# 2021-03-01  17.980000  17.750000  17.750000  17.930000  155800.0  17.930000
#
#             Simple Return  Log Return
# Date
# 1999-01-04            NaN         NaN
# 1999-01-05       0.009302    0.009346
# 1999-01-06       0.020501    0.020714
# 1999-01-07      -0.006881   -0.006857
# 1999-01-08       0.004566    0.004576
# ...                   ...         ...
# 2021-02-23      -0.001124   -0.001123
# 2021-02-24       0.012209    0.012284
# 2021-02-25      -0.020963   -0.020747
# 2021-02-26      -0.003411   -0.003405
# 2021-03-01       0.018963    0.019145
#
# [5575 rows x 8 columns]

# %%
X1 = df1.index
y1 = df1['Adj Close']

X2 = df2.index
y2 = df2['Adj Close']



plt.plot(X1,y1)
plt.plot(X2,y2)
plt.title(ticker1 + "/" + ticker2 + " Stock Price")
plt.ylabel('Price (USD)')
plt.legend([ticker1, ticker2])
plt.show()
